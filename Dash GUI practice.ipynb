# %%
# Import packages
from dash import Dash, html, dash_table, dcc
import pandas as pd
import plotly.express as px

# Incorporate data
df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/gapminder2007.csv')

# Initialize the app
app = Dash()

# App layout
app.layout = [
    html.Div(children='My First App with Data and a Graph'),
    dash_table.DataTable(data=df.to_dict('records'), page_size=10),
    dcc.Graph(figure=px.histogram(df, x='continent', y='lifeExp', histfunc='avg'))
]



# Run the app
if __name__ == '__main__':
    app.run(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# Import packages
from dash import Dash, html, dash_table, dcc, callback, Output, Input
import pandas as pd
import plotly.express as px

# Incorporate data
df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/gapminder2007.csv')

# Initialize the app
app = Dash()

# App layout
app.layout = [
    html.Div(children='My First App with Data, Graph, and Controls'),
    html.Hr(),
    dcc.RadioItems(options=['pop', 'lifeExp', 'gdpPercap'], value='lifeExp', id='controls-and-radio-item'),
    dash_table.DataTable(data=df.to_dict('records'), page_size=6),
    dcc.Graph(figure={}, id='controls-and-graph')
]

# Add controls to build the interaction
@callback(
    Output(component_id='controls-and-graph', component_property='figure'),
    Input(component_id='controls-and-radio-item', component_property='value')
)
def update_graph(col_chosen):
    fig = px.histogram(df, x='continent', y=col_chosen, histfunc='avg')
    return fig

# %%
# Run the app
if __name__ == '__main__':
    app.run(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# Import packages
from dash import Dash, html, dash_table, dcc, callback, Output, Input
import pandas as pd
import plotly.express as px

# Incorporate data
df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/gapminder2007.csv')

# Initialize the app - incorporate css
external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']
app = Dash(external_stylesheets=external_stylesheets)

# App layout
app.layout = [
    html.Div(className='row', children='My First App with Data, Graph, and Controls',
             style={'textAlign': 'center', 'color': 'blue', 'fontSize': 30}),

    html.Div(className='row', children=[
        dcc.RadioItems(options=['pop', 'lifeExp', 'gdpPercap'],
                       value='lifeExp',
                       inline=True,
                       id='my-radio-buttons-final')
    ]),

    html.Div(className='row', children=[
        html.Div(className='six columns', children=[
            dash_table.DataTable(data=df.to_dict('records'), page_size=11, style_table={'overflowX': 'auto'})
        ]),
        html.Div(className='six columns', children=[
            dcc.Graph(figure={}, id='histo-chart-final')
        ])
    ])
]

# Add controls to build the interaction
@callback(
    Output(component_id='histo-chart-final', component_property='figure'),
    Input(component_id='my-radio-buttons-final', component_property='value')
)
def update_graph(col_chosen):
    fig = px.histogram(df, x='continent', y=col_chosen, histfunc='avg')
    return fig

# Run the app
if __name__ == '__main__':
    app.run(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# [2025-07-14 11:11:24,205] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/dash.py", line 1378, in _prepare_callback
#     cb = self.callback_map[output]
#          ~~~~~~~~~~~~~~~~~^^^^^^^^
# KeyError: 'controls-and-graph.figure'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/dash.py", line 1479, in dispatch
#     func = self._prepare_callback(g, body)
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/dash.py", line 1412, in _prepare_callback
#     raise KeyError(f"Callback function not found for output '{output}'.") from e
# KeyError: "Callback function not found for output 'controls-and-graph.figure'."
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 1511, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 919, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 809, in handle_user_exception
#     return self.ensure_sync(handler)(e)  # type: ignore[no-any-return]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/_jupyter.py", line 462, in _wrap_errors
#     ipytb = FormattedTB(
#         tb_offset=skip,
#     ...<3 lines>...
#         ostream=ostream,
#     )
# TypeError: FormattedTB.__init__() got an unexpected keyword argument 'color_scheme'
# Error on request:
# Traceback (most recent call last):
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/dash.py", line 1378, in _prepare_callback
#     cb = self.callback_map[output]
#          ~~~~~~~~~~~~~~~~~^^^^^^^^
# KeyError: 'controls-and-graph.figure'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/dash.py", line 1479, in dispatch
#     func = self._prepare_callback(g, body)
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/dash.py", line 1412, in _prepare_callback
#     raise KeyError(f"Callback function not found for output '{output}'.") from e
# KeyError: "Callback function not found for output 'controls-and-graph.figure'."
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 1511, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 919, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 809, in handle_user_exception
#     return self.ensure_sync(handler)(e)  # type: ignore[no-any-return]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/_jupyter.py", line 462, in _wrap_errors
#     ipytb = FormattedTB(
#
# TypeError: FormattedTB.__init__() got an unexpected keyword argument 'color_scheme'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/werkzeug/serving.py", line 370, in run_wsgi
#     execute(self.server.app)
#     ~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/werkzeug/serving.py", line 331, in execute
#     application_iter = app(environ, start_response)
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 1536, in __call__
#     return self.wsgi_app(environ, start_response)
#            ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 1514, in wsgi_app
#     response = self.handle_exception(e)
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 860, in handle_exception
#     server_error = self.ensure_sync(handler)(server_error)
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/_jupyter.py", line 453, in _wrap_errors
#     skip = _get_skip(error) if dev_tools_prune_errors else 0
#            ~~~~~~~~~^^^^^^^
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/_jupyter.py", line 47, in _get_skip
#     while tb.tb_next is not None:
#           ^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'tb_next'
# [2025-07-14 11:11:25,348] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/dash.py", line 1378, in _prepare_callback
#     cb = self.callback_map[output]
#          ~~~~~~~~~~~~~~~~~^^^^^^^^
# KeyError: 'controls-and-graph.figure'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/dash.py", line 1479, in dispatch
#     func = self._prepare_callback(g, body)
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/dash.py", line 1412, in _prepare_callback
#     raise KeyError(f"Callback function not found for output '{output}'.") from e
# KeyError: "Callback function not found for output 'controls-and-graph.figure'."
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 1511, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 919, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 809, in handle_user_exception
#     return self.ensure_sync(handler)(e)  # type: ignore[no-any-return]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/_jupyter.py", line 462, in _wrap_errors
#     ipytb = FormattedTB(
#         tb_offset=skip,
#     ...<3 lines>...
#         ostream=ostream,
#     )
# TypeError: FormattedTB.__init__() got an unexpected keyword argument 'color_scheme'
# Error on request:
# Traceback (most recent call last):
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/dash.py", line 1378, in _prepare_callback
#     cb = self.callback_map[output]
#          ~~~~~~~~~~~~~~~~~^^^^^^^^
# KeyError: 'controls-and-graph.figure'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/dash.py", line 1479, in dispatch
#     func = self._prepare_callback(g, body)
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/dash.py", line 1412, in _prepare_callback
#     raise KeyError(f"Callback function not found for output '{output}'.") from e
# KeyError: "Callback function not found for output 'controls-and-graph.figure'."
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 1511, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 919, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 809, in handle_user_exception
#     return self.ensure_sync(handler)(e)  # type: ignore[no-any-return]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/_jupyter.py", line 462, in _wrap_errors
#     ipytb = FormattedTB(
#
# TypeError: FormattedTB.__init__() got an unexpected keyword argument 'color_scheme'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/werkzeug/serving.py", line 370, in run_wsgi
#     execute(self.server.app)
#     ~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/werkzeug/serving.py", line 331, in execute
#     application_iter = app(environ, start_response)
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 1536, in __call__
#     return self.wsgi_app(environ, start_response)
#            ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 1514, in wsgi_app
#     response = self.handle_exception(e)
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 860, in handle_exception
#     server_error = self.ensure_sync(handler)(server_error)
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/_jupyter.py", line 453, in _wrap_errors
#     skip = _get_skip(error) if dev_tools_prune_errors else 0
#            ~~~~~~~~~^^^^^^^
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/_jupyter.py", line 47, in _get_skip
#     while tb.tb_next is not None:
#           ^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'tb_next'
# [2025-07-14 11:11:43,083] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/dash.py", line 1378, in _prepare_callback
#     cb = self.callback_map[output]
#          ~~~~~~~~~~~~~~~~~^^^^^^^^
# KeyError: 'controls-and-graph.figure'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/dash.py", line 1479, in dispatch
#     func = self._prepare_callback(g, body)
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/dash.py", line 1412, in _prepare_callback
#     raise KeyError(f"Callback function not found for output '{output}'.") from e
# KeyError: "Callback function not found for output 'controls-and-graph.figure'."
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 1511, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 919, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 809, in handle_user_exception
#     return self.ensure_sync(handler)(e)  # type: ignore[no-any-return]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/_jupyter.py", line 462, in _wrap_errors
#     ipytb = FormattedTB(
#         tb_offset=skip,
#     ...<3 lines>...
#         ostream=ostream,
#     )
# TypeError: FormattedTB.__init__() got an unexpected keyword argument 'color_scheme'
# Error on request:
# Traceback (most recent call last):
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/dash.py", line 1378, in _prepare_callback
#     cb = self.callback_map[output]
#          ~~~~~~~~~~~~~~~~~^^^^^^^^
# KeyError: 'controls-and-graph.figure'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/dash.py", line 1479, in dispatch
#     func = self._prepare_callback(g, body)
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/dash.py", line 1412, in _prepare_callback
#     raise KeyError(f"Callback function not found for output '{output}'.") from e
# KeyError: "Callback function not found for output 'controls-and-graph.figure'."
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 1511, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 919, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 809, in handle_user_exception
#     return self.ensure_sync(handler)(e)  # type: ignore[no-any-return]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/_jupyter.py", line 462, in _wrap_errors
#     ipytb = FormattedTB(
#
# TypeError: FormattedTB.__init__() got an unexpected keyword argument 'color_scheme'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/werkzeug/serving.py", line 370, in run_wsgi
#     execute(self.server.app)
#     ~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/werkzeug/serving.py", line 331, in execute
#     application_iter = app(environ, start_response)
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 1536, in __call__
#     return self.wsgi_app(environ, start_response)
#            ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 1514, in wsgi_app
#     response = self.handle_exception(e)
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 860, in handle_exception
#     server_error = self.ensure_sync(handler)(server_error)
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/_jupyter.py", line 453, in _wrap_errors
#     skip = _get_skip(error) if dev_tools_prune_errors else 0
#            ~~~~~~~~~^^^^^^^
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/_jupyter.py", line 47, in _get_skip
#     while tb.tb_next is not None:
#           ^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'tb_next'
# [2025-07-14 11:11:45,931] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/dash.py", line 1378, in _prepare_callback
#     cb = self.callback_map[output]
#          ~~~~~~~~~~~~~~~~~^^^^^^^^
# KeyError: 'controls-and-graph.figure'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/dash.py", line 1479, in dispatch
#     func = self._prepare_callback(g, body)
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/dash.py", line 1412, in _prepare_callback
#     raise KeyError(f"Callback function not found for output '{output}'.") from e
# KeyError: "Callback function not found for output 'controls-and-graph.figure'."
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 1511, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 919, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 809, in handle_user_exception
#     return self.ensure_sync(handler)(e)  # type: ignore[no-any-return]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/_jupyter.py", line 462, in _wrap_errors
#     ipytb = FormattedTB(
#         tb_offset=skip,
#     ...<3 lines>...
#         ostream=ostream,
#     )
# TypeError: FormattedTB.__init__() got an unexpected keyword argument 'color_scheme'
# Error on request:
# Traceback (most recent call last):
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/dash.py", line 1378, in _prepare_callback
#     cb = self.callback_map[output]
#          ~~~~~~~~~~~~~~~~~^^^^^^^^
# KeyError: 'controls-and-graph.figure'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/dash.py", line 1479, in dispatch
#     func = self._prepare_callback(g, body)
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/dash.py", line 1412, in _prepare_callback
#     raise KeyError(f"Callback function not found for output '{output}'.") from e
# KeyError: "Callback function not found for output 'controls-and-graph.figure'."
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 1511, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 919, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 809, in handle_user_exception
#     return self.ensure_sync(handler)(e)  # type: ignore[no-any-return]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/_jupyter.py", line 462, in _wrap_errors
#     ipytb = FormattedTB(
#
# TypeError: FormattedTB.__init__() got an unexpected keyword argument 'color_scheme'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/werkzeug/serving.py", line 370, in run_wsgi
#     execute(self.server.app)
#     ~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/werkzeug/serving.py", line 331, in execute
#     application_iter = app(environ, start_response)
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 1536, in __call__
#     return self.wsgi_app(environ, start_response)
#            ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 1514, in wsgi_app
#     response = self.handle_exception(e)
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 860, in handle_exception
#     server_error = self.ensure_sync(handler)(server_error)
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/_jupyter.py", line 453, in _wrap_errors
#     skip = _get_skip(error) if dev_tools_prune_errors else 0
#            ~~~~~~~~~^^^^^^^
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/_jupyter.py", line 47, in _get_skip
#     while tb.tb_next is not None:
#           ^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'tb_next'
# [2025-07-14 11:11:49,987] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/dash.py", line 1378, in _prepare_callback
#     cb = self.callback_map[output]
#          ~~~~~~~~~~~~~~~~~^^^^^^^^
# KeyError: 'controls-and-graph.figure'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/dash.py", line 1479, in dispatch
#     func = self._prepare_callback(g, body)
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/dash.py", line 1412, in _prepare_callback
#     raise KeyError(f"Callback function not found for output '{output}'.") from e
# KeyError: "Callback function not found for output 'controls-and-graph.figure'."
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 1511, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 919, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 809, in handle_user_exception
#     return self.ensure_sync(handler)(e)  # type: ignore[no-any-return]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/_jupyter.py", line 462, in _wrap_errors
#     ipytb = FormattedTB(
#         tb_offset=skip,
#     ...<3 lines>...
#         ostream=ostream,
#     )
# TypeError: FormattedTB.__init__() got an unexpected keyword argument 'color_scheme'
# Error on request:
# Traceback (most recent call last):
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/dash.py", line 1378, in _prepare_callback
#     cb = self.callback_map[output]
#          ~~~~~~~~~~~~~~~~~^^^^^^^^
# KeyError: 'controls-and-graph.figure'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/dash.py", line 1479, in dispatch
#     func = self._prepare_callback(g, body)
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/dash.py", line 1412, in _prepare_callback
#     raise KeyError(f"Callback function not found for output '{output}'.") from e
# KeyError: "Callback function not found for output 'controls-and-graph.figure'."
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 1511, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 919, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 809, in handle_user_exception
#     return self.ensure_sync(handler)(e)  # type: ignore[no-any-return]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/_jupyter.py", line 462, in _wrap_errors
#     ipytb = FormattedTB(
#
# TypeError: FormattedTB.__init__() got an unexpected keyword argument 'color_scheme'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/werkzeug/serving.py", line 370, in run_wsgi
#     execute(self.server.app)
#     ~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/werkzeug/serving.py", line 331, in execute
#     application_iter = app(environ, start_response)
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 1536, in __call__
#     return self.wsgi_app(environ, start_response)
#            ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 1514, in wsgi_app
#     response = self.handle_exception(e)
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/flask/app.py", line 860, in handle_exception
#     server_error = self.ensure_sync(handler)(server_error)
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/_jupyter.py", line 453, in _wrap_errors
#     skip = _get_skip(error) if dev_tools_prune_errors else 0
#            ~~~~~~~~~^^^^^^^
#   File "/home/wag_user2/miniforge3/envs/astropy/lib/python3.13/site-packages/dash/_jupyter.py", line 47, in _get_skip
#     while tb.tb_next is not None:
#           ^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'tb_next'

# %%
fig = px.histogram(df, x='continent', y='pop', histfunc='avg')
fig.show()

# %%
#Dash histogram practice with Galaxy Catalog

import plotly.express as px
import pandas as pd 
import numpy as np



line_table_data = np.load('/data/projects/FIRESIDE/data/line_table_cat_v9.npy', allow_pickle=True)

df = pd.DataFrame(line_table_data[11:])
fig = px.histogram(df, x=", nbins=20)
fig.show()
# Out:
#   Cell In[8], line 12
#     fig = px.histogram(df, x=", nbins=20)
#                              ^
# SyntaxError: unterminated string literal (detected at line 12)
